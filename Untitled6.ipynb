# %% [markdown]
# <a href="https://colab.research.google.com/github/jgdeaguiarnegreiros-rgb/Oficina-de-GitHbub/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Problema Encontrado       	      | Princípio Violado	           |Justificativa
Classe acumula muitas funções	    | SRP	                         |A classe gerencia desde o carrinho de compras
                                  |                              |até o envio de e-mails e regras fiscais.
                                  |                              |
Cálculo de frete e desconto com   | OCP                          |O sistema está aberto para modificação e fechado para extensão.
if/else                           |                              |
                                  |                              |
Dependência de tipos              | DIP                          |A lógica depende de valores fixos ("pix", "sedex") em vez de interfaces ou abstrações.
concretos (strings)               |                              |
                                  |                              |
Falta de modularidade             | SRP                          |Se o serviço de e-mail falhar ou mudar de fornecedor, a classe de negócio principal precisa ser editada.
